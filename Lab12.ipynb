# %% [markdown]
# <a href="https://colab.research.google.com/github/KinzaAslam/DSA_20SW071/blob/main/Lab12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Fetch a web page
r = requests.get("https://www.usindh.edu.pk/")
print(r.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>www.usindh.edu.pk | 520: Web server is returning an unknown error</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
# ...

# %%
import re

# Remove HTML tags using RegularExpression
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
#
#
#
#
#
#
#
# www.usindh.edu.pk | 520: Web server is returning an unknown error
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Web server is returning an unknown error
#               Error code 520
#
#
#                Visit cloudflare.com for more information.
#
#             2023-10-09 09:02:44 UTC
#
#
#
#
#
#
#
#
#
#
#
#
#   You
#
#
#     Browser
#
#
#   Working
#
#
#
#
#
#
#
#
#
#   Atlanta
#
#
#     Cloudflare
#
#
#   Working
#
#
#
#
#
#
#
#
#
#   www.usindh.edu.pk
#
#
#     Host
#
#
#   Error
#
#
#
#
#
#
#
#
#
#                     What happened?
#                     There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.
#
#
#                     What can I do?
#                           If you are a visitor of this website:
#       Please try again in a few minutes.
#
#       If you are the owner of this website:
# ...

# %%
# Remove HTML tags using Beautiful Soup library
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# www.usindh.edu.pk | 520: Web server is returning an unknown error
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Web server is returning an unknown error
#               Error code 520
#
#
#                Visit cloudflare.com for more information.
#
#             2023-10-09 09:02:44 UTC
#
#
#
#
#
#
#
#
#
#
#
#
#   You
#
#
#     Browser
#
#
#   Working
#
#
#
#
#
#
#
#
#
#   Atlanta
#
#
#     Cloudflare
#
#
#   Working
#
#
#
#
#
#
#
#
#
#   www.usindh.edu.pk
#
#
#     Host
#
#
#   Error
#
#
#
#
#
#
#
#
#
#                     What happened?
#                     There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.
#
#
#                     What can I do?
#                           If you are a visitor of this website:
#       Please try again in a few minutes.
#
#       If you are the owner of this website:
# ...
